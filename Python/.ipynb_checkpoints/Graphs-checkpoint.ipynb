../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_13_39_2.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_13_39_3.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_13_39_4.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_13_39_5.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_13_39_6.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_13_39_7.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_13_39_8.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_30_8.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_30_9.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_1.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_10.txt  ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_2.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_3.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_4.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_5.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_6.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_7.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_8.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_45_9.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_1.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_10.txt  ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_2.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_3.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_4.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_5.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_6.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_7.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_8.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
# ins_15_60_9.txt   ../CPP/main -v aa -c 6 -t 1 -i ../CPP/instance...
#
# [180 rows x 4 columns]

# %%
dataset = dataset.drop(dataset.columns[0], axis=1)

# %%
dataset.columns
# Out:
# Index(['corte 0 ', 'corte 2', 'corte 6'], dtype='object')

# %%
dataset.rename(columns={"corte 0 ": "Sem Cortes", "corte 2": "Como Restricao", "corte 6": "Como Callback"}, inplace=True)

# %%
dataset_run = dataset.head(48)

# %%
dataset_run
# Out:
#                            Sem Cortes       Como Restricao  \
# file
# ins_05_10_1.txt    0.2667267322540283  0.31656408309936523
# ins_05_10_10.txt  0.16619157791137695   0.1676616668701172
# ins_05_10_2.txt   0.21611952781677246   0.2173755168914795
# ins_05_10_3.txt   0.21686315536499023  0.21776652336120605
# ins_05_10_4.txt   0.11606335639953613  0.11609125137329102
# ins_05_10_5.txt   0.16626429557800293  0.16647839546203613
# ins_05_10_6.txt   0.21610069274902344  0.16615796089172363
# ins_05_10_7.txt    0.2166576385498047  0.21712207794189453
# ins_05_10_8.txt   0.16585874557495117  0.16688871383666992
# ins_05_10_9.txt    0.3667891025543213   0.3671712875366211
# ins_05_15_1.txt    2.2218515872955322    2.321014881134033
# ins_05_15_10.txt   0.6177284717559814   0.6685917377471924
# ins_05_15_2.txt     8.033827066421509     8.73954463005066
# ins_05_15_3.txt     8.334673404693604    50.78459024429321
# ins_05_15_4.txt      3.12300181388855   3.0738725662231445
# ins_05_15_5.txt     40.15739369392395    52.34263563156128
# ins_05_15_6.txt     4.324973106384277   1.8715362548828125
# ins_05_15_8.txt     10.59169602394104    5.281514644622803
# ins_05_15_9.txt    1.2191400527954102   2.1722068786621094
# ins_05_20_1.txt     93.58099794387817    36.49961304664612
# ins_05_20_10.txt    91.92876386642456   132.29339790344238
# ins_05_20_2.txt    3.8253347873687744   11.243234872817993
# ins_05_20_3.txt     39.30577826499939   24.373675107955933
# ins_05_20_4.txt    15.602633237838745   17.610644102096558
# ins_05_20_5.txt    126.85858035087585    59.16936731338501
# ins_05_20_6.txt     40.31017875671387    32.79352855682373
# ins_05_20_7.txt     254.9531877040863   277.16987347602844
# ins_05_20_8.txt    0.5672657489776611   1.0193867683410645
# ins_05_20_9.txt    136.13538432121277    248.9969551563263
# ins_07_14_1.txt    0.7168326377868652   0.6670427322387695
# ins_07_14_10.txt  0.41695165634155273   0.5676319599151611
# ins_07_14_2.txt   0.36806392669677734    0.317293643951416
# ins_07_14_3.txt     1.419273853302002    1.220726490020752
# ins_07_14_4.txt    1.7197110652923584    5.180365324020386
# ins_11_22_9.txt                   ttl                  ttl
# ins_11_33_1.txt                   ttl                  ttl
# ins_11_33_10.txt                  ttl                  ttl
# ins_11_33_2.txt                   ttl                  ttl
# ins_11_33_3.txt                   ttl                  ttl
# ins_11_33_4.txt                   ttl                  ttl
# ins_11_33_5.txt                   ttl                  ttl
# ins_11_33_6.txt                   ttl                  ttl
# ins_11_33_7.txt                   ttl                  ttl
# ins_11_33_8.txt                   ttl                  ttl
# ins_11_33_9.txt                   ttl                  ttl
# ins_11_44_1.txt                   ttl                  ttl
# ins_11_44_10.txt                  ttl                  ttl
# ins_11_44_2.txt                   ttl                  ttl
#
#                         Como Callback
# file
# ins_05_10_1.txt   0.26647043228149414
# ins_05_10_10.txt   0.1678330898284912
# ins_05_10_2.txt   0.21734881401062012
# ins_05_10_3.txt   0.21829438209533691
# ins_05_10_4.txt   0.11687731742858887
# ins_05_10_5.txt    0.1669774055480957
# ins_05_10_6.txt   0.21625661849975586
# ins_05_10_7.txt   0.21666789054870605
# ins_05_10_8.txt   0.16739177703857422
# ins_05_10_9.txt   0.36676979064941406
# ins_05_15_1.txt      2.17452073097229
# ins_05_15_10.txt   0.6190896034240723
# ins_05_15_2.txt     8.033804655075073
# ins_05_15_3.txt     8.337392330169678
# ins_05_15_4.txt    3.1239514350891113
# ins_05_15_5.txt    40.353713512420654
# ins_05_15_6.txt     4.376361608505249
# ins_05_15_8.txt    10.535683631896973
# ins_05_15_9.txt     1.218886137008667
# ins_05_20_1.txt     95.42280530929565
# ins_05_20_10.txt     91.3800675868988
# ins_05_20_2.txt    3.8262674808502197
# ins_05_20_3.txt    39.309380769729614
# ins_05_20_4.txt    15.503148317337036
# ins_05_20_5.txt    125.60870003700256
# ins_05_20_6.txt    40.108824729919434
# ins_05_20_7.txt     255.0125653743744
# ins_05_20_8.txt    0.5693728923797607
# ins_05_20_9.txt    137.83792424201965
# ins_07_14_1.txt     0.767707347869873
# ins_07_14_10.txt  0.46895670890808105
# ins_07_14_2.txt   0.31893301010131836
# ins_07_14_3.txt     1.419574499130249
# ins_07_14_4.txt    1.7230966091156006
# ins_11_22_9.txt                   ttl
# ins_11_33_1.txt                   ttl
# ins_11_33_10.txt                  ttl
# ins_11_33_2.txt                   ttl
# ins_11_33_3.txt                   ttl
# ins_11_33_4.txt                   ttl
# ins_11_33_5.txt                   ttl
# ins_11_33_6.txt                   ttl
# ins_11_33_7.txt                   ttl
# ins_11_33_8.txt                   ttl
# ins_11_33_9.txt                   ttl
# ins_11_44_1.txt                   ttl
# ins_11_44_10.txt                  ttl
# ins_11_44_2.txt                   ttl

# %%
len(dataset_run)
# Out:
# 48

# %%
dataset_run.tail(14)
# Out:
#                  Sem Cortes Como Restricao Como Callback
# file
# ins_11_22_9.txt         ttl            ttl           ttl
# ins_11_33_1.txt         ttl            ttl           ttl
# ins_11_33_10.txt        ttl            ttl           ttl
# ins_11_33_2.txt         ttl            ttl           ttl
# ins_11_33_3.txt         ttl            ttl           ttl
# ins_11_33_4.txt         ttl            ttl           ttl
# ins_11_33_5.txt         ttl            ttl           ttl
# ins_11_33_6.txt         ttl            ttl           ttl
# ins_11_33_7.txt         ttl            ttl           ttl
# ins_11_33_8.txt         ttl            ttl           ttl
# ins_11_33_9.txt         ttl            ttl           ttl
# ins_11_44_1.txt         ttl            ttl           ttl
# ins_11_44_10.txt        ttl            ttl           ttl
# ins_11_44_2.txt         ttl            ttl           ttl

# %%
dataset_run_replaced = dataset_run.replace("ttl", 3600)

# %%
dataset_run_replaced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, ins_05_10_1.txt to ins_11_44_2.txt
# Data columns (total 3 columns):
# Sem Cortes        48 non-null object
# Como Restricao    48 non-null object
# Como Callback     48 non-null object
# dtypes: object(3)
# memory usage: 1.5+ KB

# %%
for column in dataset_run_replaced.columns:
    print(column)
    dataset_run_replaced[column] = dataset_run_replaced[column].astype(float)
# Out:
# Sem Cortes
# Como Restricao
# Como Callback

# %%
dataset_run_replaced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, ins_05_10_1.txt to ins_11_44_2.txt
# Data columns (total 3 columns):
# Sem Cortes        48 non-null float64
# Como Restricao    48 non-null float64
# Como Callback     48 non-null float64
# dtypes: float64(3)
# memory usage: 1.5+ KB

# %%
dataset_run_replaced.describe()
# Out:
#         Sem Cortes  Como Restricao  Como Callback
# count    48.000000       48.000000      48.000000
# mean   1068.509310     1070.385365    1068.545242
# std    1642.260903     1641.314658    1642.239777
# min       0.116063        0.116091       0.116877
# 25%       0.529687        0.642190       0.544269
# 50%       9.463185       14.426939       9.436538
# 75%    3600.000000     3600.000000    3600.000000
# max    3600.000000     3600.000000    3600.000000

# %%
dataset_run_replaced.boxplot()

# %%
dataset_run_replaced.head()
# Out:
#                   Sem Cortes  Como Restricao  Como Callback
# file
# ins_05_10_1.txt     0.266727        0.316564       0.266470
# ins_05_10_10.txt    0.166192        0.167662       0.167833
# ins_05_10_2.txt     0.216120        0.217376       0.217349
# ins_05_10_3.txt     0.216863        0.217767       0.218294
# ins_05_10_4.txt     0.116063        0.116091       0.116877

# %%
data = dataset_run_replaced
index = data.index

# %%
data.index
# Out:
# Index(['ins_05_10_1.txt', 'ins_05_10_10.txt', 'ins_05_10_2.txt',
#        'ins_05_10_3.txt', 'ins_05_10_4.txt', 'ins_05_10_5.txt',
#        'ins_05_10_6.txt', 'ins_05_10_7.txt', 'ins_05_10_8.txt',
#        'ins_05_10_9.txt', 'ins_05_15_1.txt', 'ins_05_15_10.txt',
#        'ins_05_15_2.txt', 'ins_05_15_3.txt', 'ins_05_15_4.txt',
#        'ins_05_15_5.txt', 'ins_05_15_6.txt', 'ins_05_15_8.txt',
#        'ins_05_15_9.txt', 'ins_05_20_1.txt', 'ins_05_20_10.txt',
#        'ins_05_20_2.txt', 'ins_05_20_3.txt', 'ins_05_20_4.txt',
#        'ins_05_20_5.txt', 'ins_05_20_6.txt', 'ins_05_20_7.txt',
#        'ins_05_20_8.txt', 'ins_05_20_9.txt', 'ins_07_14_1.txt',
#        'ins_07_14_10.txt', 'ins_07_14_2.txt', 'ins_07_14_3.txt',
#        'ins_07_14_4.txt', 'ins_11_22_9.txt', 'ins_11_33_1.txt',
#        'ins_11_33_10.txt', 'ins_11_33_2.txt', 'ins_11_33_3.txt',
#        'ins_11_33_4.txt', 'ins_11_33_5.txt', 'ins_11_33_6.txt',
#        'ins_11_33_7.txt', 'ins_11_33_8.txt', 'ins_11_33_9.txt',
#        'ins_11_44_1.txt', 'ins_11_44_10.txt', 'ins_11_44_2.txt'],
#       dtype='object', name='file')

# %% [markdown]
# # EXCEL

# %%
def TO_EXCEL(data, size_end, excel_file, size_start = 1):
    '''
    TO_EXCEL(data, size_end, excel_file, size_start = 1)
    '''
    
    # Create a Pandas dataframe from the data.
    df = pd.DataFrame(data, index=data.index)

    # Create a Pandas Excel writer using XlsxWriter as the engine.
    #excel_file = 'graph.xlsx'
    sheet_name = 'Sheet1'

    writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
    df.to_excel(writer, sheet_name=sheet_name)

    # Access the XlsxWriter workbook and worksheet objects from the dataframe.
    workbook = writer.book
    worksheet = writer.sheets[sheet_name]

    # Create a chart object.
    chart = workbook.add_chart({'type': 'column'})

    # Configure the series of the chart from the dataframe data.
    for col_num in range(1, 4):
        chart.add_series({
            'name':       ['Sheet1', 0, col_num],
            'categories': ['Sheet1', 1, 0, size_end, 0],
            'values':     ['Sheet1', size_start, col_num, size_end, col_num],
            'fill':       {'color': brews['Set1'][col_num - 1]},
            'overlap':-10,
        })

    # Configure the chart axes.
    chart.set_x_axis({'name': 'Instancia'})
    chart.set_y_axis({'name': 'Tempo', 'major_gridlines': {'visible': False}})

    # Insert the chart into the worksheet.
    worksheet.insert_chart('H2', chart)

    # Close the Pandas Excel writer and output the Excel file.
    writer.save()

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame(data, index=index)

# Create a Pandas Excel writer using XlsxWriter as the engine.
excel_file = 'graph.xlsx'
sheet_name = 'Sheet1'

writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
df.to_excel(writer, sheet_name=sheet_name)

# Access the XlsxWriter workbook and worksheet objects from the dataframe.
workbook = writer.book
worksheet = writer.sheets[sheet_name]

# Create a chart object.
chart = workbook.add_chart({'type': 'column'})

# Configure the series of the chart from the dataframe data.
for col_num in range(1, 4):
    chart.add_series({
        'name':       ['Sheet1', 0, col_num],
        'categories': ['Sheet1', 1, 0, 48, 0],
        'values':     ['Sheet1', 1, col_num, 48, col_num],
        'fill':       {'color': brews['Set1'][col_num - 1]},
        'overlap':-10,
    })

# Configure the chart axes.
chart.set_x_axis({'name': 'Instancia'})
chart.set_y_axis({'name': 'Tempo', 'major_gridlines': {'visible': False}})

# Insert the chart into the worksheet.
worksheet.insert_chart('H2', chart)

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
len(data.head(1))
# Out:
# 1

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame(data, index=index)

# Create a Pandas Excel writer using XlsxWriter as the engine.
excel_file = 'graphClean.xlsx'
sheet_name = 'Sheet1'

writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
df.to_excel(writer, sheet_name=sheet_name)

# Access the XlsxWriter workbook and worksheet objects from the dataframe.
workbook = writer.book
worksheet = writer.sheets[sheet_name]

# Create a chart object.
chart = workbook.add_chart({'type': 'column'})

entries = 34

# Configure the series of the chart from the dataframe data.
for col_num in range(1, 4):
    chart.add_series({
        'name':       ['Sheet1', 0, col_num],
        'categories': ['Sheet1', 1, 0, entries, 0],
        'values':     ['Sheet1', 1, col_num, entries, col_num],
        'fill':       {'color': brews['Set1'][col_num - 1]},
        'overlap':-10,
    })

# Configure the chart axes.
chart.set_x_axis({'name': 'Instancia'})
chart.set_y_axis({'name': 'Tempo', 'major_gridlines': {'visible': False}})

# Insert the chart into the worksheet.
worksheet.insert_chart('H2', chart)

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame(data, index=index)

# Create a Pandas Excel writer using XlsxWriter as the engine.
excel_file = 'graphClean2.xlsx'
sheet_name = 'Sheet1'

writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
df.to_excel(writer, sheet_name=sheet_name)

# Access the XlsxWriter workbook and worksheet objects from the dataframe.
workbook = writer.book
worksheet = writer.sheets[sheet_name]

# Create a chart object.
chart = workbook.add_chart({'type': 'column'})

entries = 12

# Configure the series of the chart from the dataframe data.
for col_num in range(1, 4):
    chart.add_series({
        'name':       ['Sheet1', 0, col_num],
        'categories': ['Sheet1', 1, 0, entries, 0],
        'values':     ['Sheet1', 1, col_num, entries, col_num],
        'fill':       {'color': brews['Set1'][col_num - 1]},
        'overlap':-10,
    })

# Configure the chart axes.
chart.set_x_axis({'name': 'Instancia'})
chart.set_y_axis({'name': 'Tempo', 'major_gridlines': {'visible': False}})

# Insert the chart into the worksheet.
worksheet.insert_chart('H2', chart)

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
data
# Out:
#                    Sem Cortes  Como Restricao  Como Callback
# file
# ins_05_10_1.txt      0.266727        0.316564       0.266470
# ins_05_10_10.txt     0.166192        0.167662       0.167833
# ins_05_10_2.txt      0.216120        0.217376       0.217349
# ins_05_10_3.txt      0.216863        0.217767       0.218294
# ins_05_10_4.txt      0.116063        0.116091       0.116877
# ins_05_10_5.txt      0.166264        0.166478       0.166977
# ins_05_10_6.txt      0.216101        0.166158       0.216257
# ins_05_10_7.txt      0.216658        0.217122       0.216668
# ins_05_10_8.txt      0.165859        0.166889       0.167392
# ins_05_10_9.txt      0.366789        0.367171       0.366770
# ins_05_15_1.txt      2.221852        2.321015       2.174521
# ins_05_15_10.txt     0.617728        0.668592       0.619090
# ins_05_15_2.txt      8.033827        8.739545       8.033805
# ins_05_15_3.txt      8.334673       50.784590       8.337392
# ins_05_15_4.txt      3.123002        3.073873       3.123951
# ins_05_15_5.txt     40.157394       52.342636      40.353714
# ins_05_15_6.txt      4.324973        1.871536       4.376362
# ins_05_15_8.txt     10.591696        5.281515      10.535684
# ins_05_15_9.txt      1.219140        2.172207       1.218886
# ins_05_20_1.txt     93.580998       36.499613      95.422805
# ins_05_20_10.txt    91.928764      132.293398      91.380068
# ins_05_20_2.txt      3.825335       11.243235       3.826267
# ins_05_20_3.txt     39.305778       24.373675      39.309381
# ins_05_20_4.txt     15.602633       17.610644      15.503148
# ins_05_20_5.txt    126.858580       59.169367     125.608700
# ins_05_20_6.txt     40.310179       32.793529      40.108825
# ins_05_20_7.txt    254.953188      277.169873     255.012565
# ins_05_20_8.txt      0.567266        1.019387       0.569373
# ins_05_20_9.txt    136.135384      248.996955     137.837924
# ins_07_14_1.txt      0.716833        0.667043       0.767707
# ins_07_14_10.txt     0.416952        0.567632       0.468957
# ins_07_14_2.txt      0.368064        0.317294       0.318933
# ins_07_14_3.txt      1.419274        1.220726       1.419574
# ins_07_14_4.txt      1.719711        5.180365       1.723097
# ins_11_22_9.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_1.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_10.txt  3600.000000     3600.000000    3600.000000
# ins_11_33_2.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_3.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_4.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_5.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_6.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_7.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_8.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_9.txt   3600.000000     3600.000000    3600.000000
# ins_11_44_1.txt   3600.000000     3600.000000    3600.000000
# ins_11_44_10.txt  3600.000000     3600.000000    3600.000000
# ins_11_44_2.txt   3600.000000     3600.000000    3600.000000

# %%
def nan_all_but_min(df):
    arr = df.values
    idx = np.argmin(arr, axis=1)
    newarr = np.full_like(arr, np.nan, dtype='float')
    newarr[np.arange(arr.shape[0]), idx] = arr[np.arange(arr.shape[0]), idx]
    df = pd.DataFrame(newarr, columns=df.columns, index=df.index)
    return df

df = pd.DataFrame(data)
print(df)

df = nan_all_but_min(df)
print(df)
# Out:
#                    Sem Cortes  Como Restricao  Como Callback
# file
# ins_05_10_1.txt      0.266727        0.316564       0.266470
# ins_05_10_10.txt     0.166192        0.167662       0.167833
# ins_05_10_2.txt      0.216120        0.217376       0.217349
# ins_05_10_3.txt      0.216863        0.217767       0.218294
# ins_05_10_4.txt      0.116063        0.116091       0.116877
# ins_05_10_5.txt      0.166264        0.166478       0.166977
# ins_05_10_6.txt      0.216101        0.166158       0.216257
# ins_05_10_7.txt      0.216658        0.217122       0.216668
# ins_05_10_8.txt      0.165859        0.166889       0.167392
# ins_05_10_9.txt      0.366789        0.367171       0.366770
# ins_05_15_1.txt      2.221852        2.321015       2.174521
# ins_05_15_10.txt     0.617728        0.668592       0.619090
# ins_05_15_2.txt      8.033827        8.739545       8.033805
# ins_05_15_3.txt      8.334673       50.784590       8.337392
# ins_05_15_4.txt      3.123002        3.073873       3.123951
# ins_05_15_5.txt     40.157394       52.342636      40.353714
# ins_05_15_6.txt      4.324973        1.871536       4.376362
# ins_05_15_8.txt     10.591696        5.281515      10.535684
# ins_05_15_9.txt      1.219140        2.172207       1.218886
# ins_05_20_1.txt     93.580998       36.499613      95.422805
# ins_05_20_10.txt    91.928764      132.293398      91.380068
# ins_05_20_2.txt      3.825335       11.243235       3.826267
# ins_05_20_3.txt     39.305778       24.373675      39.309381
# ins_05_20_4.txt     15.602633       17.610644      15.503148
# ins_05_20_5.txt    126.858580       59.169367     125.608700
# ins_05_20_6.txt     40.310179       32.793529      40.108825
# ins_05_20_7.txt    254.953188      277.169873     255.012565
# ins_05_20_8.txt      0.567266        1.019387       0.569373
# ins_05_20_9.txt    136.135384      248.996955     137.837924
# ins_07_14_1.txt      0.716833        0.667043       0.767707
# ins_07_14_10.txt     0.416952        0.567632       0.468957
# ins_07_14_2.txt      0.368064        0.317294       0.318933
# ins_07_14_3.txt      1.419274        1.220726       1.419574
# ins_07_14_4.txt      1.719711        5.180365       1.723097
# ins_11_22_9.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_1.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_10.txt  3600.000000     3600.000000    3600.000000
# ins_11_33_2.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_3.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_4.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_5.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_6.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_7.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_8.txt   3600.000000     3600.000000    3600.000000
# ins_11_33_9.txt   3600.000000     3600.000000    3600.000000
# ins_11_44_1.txt   3600.000000     3600.000000    3600.000000
# ins_11_44_10.txt  3600.000000     3600.000000    3600.000000
# ins_11_44_2.txt   3600.000000     3600.000000    3600.000000
#                    Sem Cortes  Como Restricao  Como Callback
# file
# ins_05_10_1.txt           NaN             NaN       0.266470
# ins_05_10_10.txt     0.166192             NaN            NaN
# ins_05_10_2.txt      0.216120             NaN            NaN
# ins_05_10_3.txt      0.216863             NaN            NaN
# ins_05_10_4.txt      0.116063             NaN            NaN
# ins_05_10_5.txt      0.166264             NaN            NaN
# ins_05_10_6.txt           NaN        0.166158            NaN
# ins_05_10_7.txt      0.216658             NaN            NaN
# ins_05_10_8.txt      0.165859             NaN            NaN
# ins_05_10_9.txt           NaN             NaN       0.366770
# ins_05_15_1.txt           NaN             NaN       2.174521
# ins_05_15_10.txt     0.617728             NaN            NaN
# ins_05_15_2.txt           NaN             NaN       8.033805
# ins_05_15_3.txt      8.334673             NaN            NaN
# ins_05_15_4.txt           NaN        3.073873            NaN
# ins_05_15_5.txt     40.157394             NaN            NaN
# ins_05_15_6.txt           NaN        1.871536            NaN
# ins_05_15_8.txt           NaN        5.281515            NaN
# ins_05_15_9.txt           NaN             NaN       1.218886
# ins_05_20_1.txt           NaN       36.499613            NaN
# ins_05_20_10.txt          NaN             NaN      91.380068
# ins_05_20_2.txt      3.825335             NaN            NaN
# ins_05_20_3.txt           NaN       24.373675            NaN
# ins_05_20_4.txt           NaN             NaN      15.503148
# ins_05_20_5.txt           NaN       59.169367            NaN
# ins_05_20_6.txt           NaN       32.793529            NaN
# ins_05_20_7.txt    254.953188             NaN            NaN
# ins_05_20_8.txt      0.567266             NaN            NaN
# ins_05_20_9.txt    136.135384             NaN            NaN
# ins_07_14_1.txt           NaN        0.667043            NaN
# ins_07_14_10.txt     0.416952             NaN            NaN
# ins_07_14_2.txt           NaN        0.317294            NaN
# ins_07_14_3.txt           NaN        1.220726            NaN
# ins_07_14_4.txt      1.719711             NaN            NaN
# ins_11_22_9.txt   3600.000000             NaN            NaN
# ins_11_33_1.txt   3600.000000             NaN            NaN
# ins_11_33_10.txt  3600.000000             NaN            NaN
# ins_11_33_2.txt   3600.000000             NaN            NaN
# ins_11_33_3.txt   3600.000000             NaN            NaN
# ins_11_33_4.txt   3600.000000             NaN            NaN
# ins_11_33_5.txt   3600.000000             NaN            NaN
# ins_11_33_6.txt   3600.000000             NaN            NaN
# ins_11_33_7.txt   3600.000000             NaN            NaN
# ins_11_33_8.txt   3600.000000             NaN            NaN
# ins_11_33_9.txt   3600.000000             NaN            NaN
# ins_11_44_1.txt   3600.000000             NaN            NaN
# ins_11_44_10.txt  3600.000000             NaN            NaN
# ins_11_44_2.txt   3600.000000             NaN            NaN

# %%
df_clean = df.head(34)
df_clean
# Out:
#                   Sem Cortes  Como Restricao  Como Callback
# file
# ins_05_10_1.txt          NaN             NaN       0.266470
# ins_05_10_10.txt    0.166192             NaN            NaN
# ins_05_10_2.txt     0.216120             NaN            NaN
# ins_05_10_3.txt     0.216863             NaN            NaN
# ins_05_10_4.txt     0.116063             NaN            NaN
# ins_05_10_5.txt     0.166264             NaN            NaN
# ins_05_10_6.txt          NaN        0.166158            NaN
# ins_05_10_7.txt     0.216658             NaN            NaN
# ins_05_10_8.txt     0.165859             NaN            NaN
# ins_05_10_9.txt          NaN             NaN       0.366770
# ins_05_15_1.txt          NaN             NaN       2.174521
# ins_05_15_10.txt    0.617728             NaN            NaN
# ins_05_15_2.txt          NaN             NaN       8.033805
# ins_05_15_3.txt     8.334673             NaN            NaN
# ins_05_15_4.txt          NaN        3.073873            NaN
# ins_05_15_5.txt    40.157394             NaN            NaN
# ins_05_15_6.txt          NaN        1.871536            NaN
# ins_05_15_8.txt          NaN        5.281515            NaN
# ins_05_15_9.txt          NaN             NaN       1.218886
# ins_05_20_1.txt          NaN       36.499613            NaN
# ins_05_20_10.txt         NaN             NaN      91.380068
# ins_05_20_2.txt     3.825335             NaN            NaN
# ins_05_20_3.txt          NaN       24.373675            NaN
# ins_05_20_4.txt          NaN             NaN      15.503148
# ins_05_20_5.txt          NaN       59.169367            NaN
# ins_05_20_6.txt          NaN       32.793529            NaN
# ins_05_20_7.txt   254.953188             NaN            NaN
# ins_05_20_8.txt     0.567266             NaN            NaN
# ins_05_20_9.txt   136.135384             NaN            NaN
# ins_07_14_1.txt          NaN        0.667043            NaN
# ins_07_14_10.txt    0.416952             NaN            NaN
# ins_07_14_2.txt          NaN        0.317294            NaN
# ins_07_14_3.txt          NaN        1.220726            NaN
# ins_07_14_4.txt     1.719711             NaN            NaN

# %%
df_clean[df_clean > 0] = 1
df_clean
# Out:
# /home/lucasnn/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/lucasnn/.local/lib/python3.6/site-packages/pandas/core/frame.py:3414: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)
#                   Sem Cortes  Como Restricao  Como Callback
# file
# ins_05_10_1.txt          NaN             NaN            1.0
# ins_05_10_10.txt         1.0             NaN            NaN
# ins_05_10_2.txt          1.0             NaN            NaN
# ins_05_10_3.txt          1.0             NaN            NaN
# ins_05_10_4.txt          1.0             NaN            NaN
# ins_05_10_5.txt          1.0             NaN            NaN
# ins_05_10_6.txt          NaN             1.0            NaN
# ins_05_10_7.txt          1.0             NaN            NaN
# ins_05_10_8.txt          1.0             NaN            NaN
# ins_05_10_9.txt          NaN             NaN            1.0
# ins_05_15_1.txt          NaN             NaN            1.0
# ins_05_15_10.txt         1.0             NaN            NaN
# ins_05_15_2.txt          NaN             NaN            1.0
# ins_05_15_3.txt          1.0             NaN            NaN
# ins_05_15_4.txt          NaN             1.0            NaN
# ins_05_15_5.txt          1.0             NaN            NaN
# ins_05_15_6.txt          NaN             1.0            NaN
# ins_05_15_8.txt          NaN             1.0            NaN
# ins_05_15_9.txt          NaN             NaN            1.0
# ins_05_20_1.txt          NaN             1.0            NaN
# ins_05_20_10.txt         NaN             NaN            1.0
# ins_05_20_2.txt          1.0             NaN            NaN
# ins_05_20_3.txt          NaN             1.0            NaN
# ins_05_20_4.txt          NaN             NaN            1.0
# ins_05_20_5.txt          NaN             1.0            NaN
# ins_05_20_6.txt          NaN             1.0            NaN
# ins_05_20_7.txt          1.0             NaN            NaN
# ins_05_20_8.txt          1.0             NaN            NaN
# ins_05_20_9.txt          1.0             NaN            NaN
# ins_07_14_1.txt          NaN             1.0            NaN
# ins_07_14_10.txt         1.0             NaN            NaN
# ins_07_14_2.txt          NaN             1.0            NaN
# ins_07_14_3.txt          NaN             1.0            NaN
# ins_07_14_4.txt          1.0             NaN            NaN

# %%
df_clean.fillna(0)
# Out:
#                   Sem Cortes  Como Restricao  Como Callback
# file
# ins_05_10_1.txt          0.0             0.0            1.0
# ins_05_10_10.txt         1.0             0.0            0.0
# ins_05_10_2.txt          1.0             0.0            0.0
# ins_05_10_3.txt          1.0             0.0            0.0
# ins_05_10_4.txt          1.0             0.0            0.0
# ins_05_10_5.txt          1.0             0.0            0.0
# ins_05_10_6.txt          0.0             1.0            0.0
# ins_05_10_7.txt          1.0             0.0            0.0
# ins_05_10_8.txt          1.0             0.0            0.0
# ins_05_10_9.txt          0.0             0.0            1.0
# ins_05_15_1.txt          0.0             0.0            1.0
# ins_05_15_10.txt         1.0             0.0            0.0
# ins_05_15_2.txt          0.0             0.0            1.0
# ins_05_15_3.txt          1.0             0.0            0.0
# ins_05_15_4.txt          0.0             1.0            0.0
# ins_05_15_5.txt          1.0             0.0            0.0
# ins_05_15_6.txt          0.0             1.0            0.0
# ins_05_15_8.txt          0.0             1.0            0.0
# ins_05_15_9.txt          0.0             0.0            1.0
# ins_05_20_1.txt          0.0             1.0            0.0
# ins_05_20_10.txt         0.0             0.0            1.0
# ins_05_20_2.txt          1.0             0.0            0.0
# ins_05_20_3.txt          0.0             1.0            0.0
# ins_05_20_4.txt          0.0             0.0            1.0
# ins_05_20_5.txt          0.0             1.0            0.0
# ins_05_20_6.txt          0.0             1.0            0.0
# ins_05_20_7.txt          1.0             0.0            0.0
# ins_05_20_8.txt          1.0             0.0            0.0
# ins_05_20_9.txt          1.0             0.0            0.0
# ins_07_14_1.txt          0.0             1.0            0.0
# ins_07_14_10.txt         1.0             0.0            0.0
# ins_07_14_2.txt          0.0             1.0            0.0
# ins_07_14_3.txt          0.0             1.0            0.0
# ins_07_14_4.txt          1.0             0.0            0.0

# %%
index_sCortes = df_clean.loc[df_clean['Sem Cortes'] == 1].index
index_sCortes = list(index_sCortes)

# %%
index_restricao = df_clean.loc[df_clean['Como Restricao'] == 1].index
index_restricao = list(index_restricao)

# %%
index_callback = df_clean.loc[df_clean['Como Callback'] == 1].index
index_callback = list(index_callback)

# %%
data.columns
# Out:
# Index(['Sem Cortes', 'Como Restricao', 'Como Callback'], dtype='object')

# %%
data_sCortes = data.loc[index_sCortes, data.columns]

# %%
data_restricao = data.loc[index_restricao, data.columns]

# %%
data_callback = data.loc[index_callback, data.columns]

# %%
TO_EXCEL(data_sCortes, len(data_sCortes),"10 sCortes.xlsx")

# %%
TO_EXCEL(data_restricao, len(data_restricao), "11 restricao.xlsx")

# %%
TO_EXCEL(data_callback, len(data_callback), "12 callback.xlsx")

# %%
df_clean.describe()
# Out:
#        Sem Cortes  Como Restricao  Como Callback
# count        16.0            11.0            7.0
# mean          1.0             1.0            1.0
# std           0.0             0.0            0.0
# min           1.0             1.0            1.0
# 25%           1.0             1.0            1.0
# 50%           1.0             1.0            1.0
# 75%           1.0             1.0            1.0
# max           1.0             1.0            1.0

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame(df_clean, index=df_clean.index)

# Create a Pandas Excel writer using XlsxWriter as the engine.
excel_file = 'graphNorm.xlsx'
sheet_name = 'Sheet1'

writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
df.to_excel(writer, sheet_name=sheet_name)

# Access the XlsxWriter workbook and worksheet objects from the dataframe.
workbook = writer.book
worksheet = writer.sheets[sheet_name]

# Create a chart object.
chart = workbook.add_chart({'type': 'column'})

entries = 34

# Configure the series of the chart from the dataframe data.
for col_num in range(1, 4):
    chart.add_series({
        'name':       ['Sheet1', 0, col_num],
        'categories': ['Sheet1', 1, 0, entries, 0],
        'values':     ['Sheet1', 1, col_num, entries, col_num],
        'fill':       {'color': brews['Set1'][col_num - 1]},
        'overlap':-10,
    })

# Configure the chart axes.
chart.set_x_axis({'name': 'Instancia'})
chart.set_y_axis({'name': 'Tempo', 'major_gridlines': {'visible': False}})

# Insert the chart into the worksheet.
worksheet.insert_chart('H2', chart)

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
df_sortvalues = data.sort_values(data.columns[0], ascending=True)

# %%
# Create a Pandas dataframe from the data.
df = pd.DataFrame(df_sortvalues, index=df_sortvalues.index)

# Create a Pandas Excel writer using XlsxWriter as the engine.
excel_file = 'graphSort.xlsx'
sheet_name = 'Sheet1'

writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')
df.to_excel(writer, sheet_name=sheet_name)

# Access the XlsxWriter workbook and worksheet objects from the dataframe.
workbook = writer.book
worksheet = writer.sheets[sheet_name]

# Create a chart object.
chart = workbook.add_chart({'type': 'column'})

entries = 34

# Configure the series of the chart from the dataframe data.
for col_num in range(1, 4):
    chart.add_series({
        'name':       ['Sheet1', 0, col_num],
        'categories': ['Sheet1', 1, 0, entries, 0],
        'values':     ['Sheet1', 18, col_num, entries, col_num],
        'fill':       {'color': brews['Set1'][col_num - 1]},
        'overlap':-10,
    })

# Configure the chart axes.
chart.set_x_axis({'name': 'Instancia'})
chart.set_y_axis({'name': 'Tempo', 'major_gridlines': {'visible': False}})

# Insert the chart into the worksheet.
worksheet.insert_chart('H2', chart)

# Close the Pandas Excel writer and output the Excel file.
writer.save()
